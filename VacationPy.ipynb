# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID              City      Lat       Lng  Max Temp  Humidity  \
# 0        0      port lincoln -34.7333  135.8667     13.58        73
# 1        1  minas de marcona -15.2119  -75.1103     20.08        63
# 2        2       yellowknife  62.4560 -114.3525     14.29        51
# 3        3          waitangi -43.9535 -176.5597     15.46        95
# 4        4             vadso  70.0744   29.7487      3.09        81
#
#    Cloudiness  Wind Speed Country        Date
# 0           3        2.90      AU  1683577467
# 1           4        6.70      PE  1683577468
# 2          75        2.57      CA  1683577194
# 3         100        3.13      NZ  1683577468
# 4          75        5.66      NO  1683577468

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
mapped_city= city_data_df.hvplot.points(
    'Lng',
    'Lat',
    geo= True,
    size= 'Humidity',
    scale= 1,
    color= 'City',
    alpha=.5,
    tiles= 'CartoLight',
    frame_width= 750,
    frame_height= 500,
    hover_cols= ['City', 'Country'],
    xlabel='Latidute',
    ylabel= 'Longitude',
    title= 'Mapped Cities from Data'
)
# Display the map
mapped_city
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
paradise_df= city_data_df.loc[(city_data_df['Humidity'] <55) & (city_data_df['Cloudiness'] <35)]
paradise_df
# Out:
#      City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 14        14       bethel  41.3712  -73.4140     24.79        35           0
# 17        17       albany  42.6001  -73.9662     21.99        34           7
# 19        19    ituiutaba -18.9689  -49.4650     27.48        51          14
# 41        41   strezhevoy  60.7333   77.5889      1.89        53           7
# 48        48         tura  25.5198   90.2201     23.94        32           0
# ..       ...          ...      ...       ...       ...       ...         ...
# 539      539     smithers  54.7804 -127.1743     14.18        38          20
# 545      545      klyuchi  52.2667   79.1667     18.11        25          31
# 554      554       ottawa  45.4112  -75.6981     18.02        25          20
# 558      558     talagang  32.9297   72.4158     21.29        44           0
# 560      560  sao vicente -23.9631  -46.3919     31.10        47           3
#
#      Wind Speed Country        Date
# 14         4.63      US  1683577472
# 17         1.34      US  1683577361
# 19         0.97      BR  1683577474
# 41         7.11      RU  1683577479
# 48         2.07      IN  1683577481
# ..          ...     ...         ...
# 539        3.09      CA  1683577638
# 545        3.76      RU  1683577640
# 554        5.66      CA  1683577492
# 558        2.58      PK  1683577644
# 560        3.13      BR  1683577645
#
# [90 rows x 10 columns]

# %%
# Drop any rows with null values
paradise_df.dropna(how= 'any', inplace= True)
paradise_df
# Out:
# C:\Users\edmon\AppData\Local\Temp\ipykernel_30948\1446000291.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   paradise_df.dropna(how= 'any', inplace= True)
#      City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 14        14       bethel  41.3712  -73.4140     24.79        35           0
# 17        17       albany  42.6001  -73.9662     21.99        34           7
# 19        19    ituiutaba -18.9689  -49.4650     27.48        51          14
# 41        41   strezhevoy  60.7333   77.5889      1.89        53           7
# 48        48         tura  25.5198   90.2201     23.94        32           0
# ..       ...          ...      ...       ...       ...       ...         ...
# 539      539     smithers  54.7804 -127.1743     14.18        38          20
# 545      545      klyuchi  52.2667   79.1667     18.11        25          31
# 554      554       ottawa  45.4112  -75.6981     18.02        25          20
# 558      558     talagang  32.9297   72.4158     21.29        44           0
# 560      560  sao vicente -23.9631  -46.3919     31.10        47           3
#
#      Wind Speed Country        Date
# 14         4.63      US  1683577472
# 17         1.34      US  1683577361
# 19         0.97      BR  1683577474
# 41         7.11      RU  1683577479
# 48         2.07      IN  1683577481
# ..          ...     ...         ...
# 539        3.09      CA  1683577638
# 545        3.76      RU  1683577640
# 554        5.66      CA  1683577492
# 558        2.58      PK  1683577644
# 560        3.13      BR  1683577645
#
# [89 rows x 10 columns]

# %%
# Display sample data
paradise_df.head()
# Out:
#     City_ID        City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 14       14      bethel  41.3712 -73.4140     24.79        35           0
# 17       17      albany  42.6001 -73.9662     21.99        34           7
# 19       19   ituiutaba -18.9689 -49.4650     27.48        51          14
# 41       41  strezhevoy  60.7333  77.5889      1.89        53           7
# 48       48        tura  25.5198  90.2201     23.94        32           0
#
#     Wind Speed Country        Date
# 14        4.63      US  1683577472
# 17        1.34      US  1683577361
# 19        0.97      BR  1683577474
# 41        7.11      RU  1683577479
# 48        2.07      IN  1683577481

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df = paradise_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()
hotel_df['Hotel Name']= ''
# Display sample data
hotel_df.head()
# Out:
#           City Country      Lat      Lng  Humidity Hotel Name
# 14      bethel      US  41.3712 -73.4140        35
# 17      albany      US  42.6001 -73.9662        34
# 19   ituiutaba      BR -18.9689 -49.4650        51
# 41  strezhevoy      RU  60.7333  77.5889        53
# 48        tura      IN  25.5198  90.2201        32

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
categories= 'accommodation.hotel'
limit= 10

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude= row['Lat']
    longitude= row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    filters= f'circle:{longitude},{latitude},{radius}'
    bias= f'proximity:{longitude},{latitude}'
    params = {
    "categories": categories,
    "limit": limit,
    "filter": filters,
    "bias": bias,
    "apiKey": geoapify_key
    }
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# bethel - nearest hotel: Hampton Inn Danbury
# albany - nearest hotel: No hotel found
# ituiutaba - nearest hotel: Hotel Bernal
# strezhevoy - nearest hotel: Гостиница "Сибирячка"
# tura - nearest hotel: No hotel found
# batalha - nearest hotel: No hotel found
# talgram - nearest hotel: No hotel found
# freeport - nearest hotel: The Freeport Inn and Marina
# isfana - nearest hotel: гост.Дилбар
# kitimat - nearest hotel: MStar Hotel
# santa marta - nearest hotel: Casa Mita
# woolgoolga - nearest hotel: Darlington Beach Resort
# coahuayana de hidalgo - nearest hotel: No hotel found
# san pedro pochutla - nearest hotel: Olimpia
# al qadarif - nearest hotel: No hotel found
# newman - nearest hotel: No hotel found
# ha'il - nearest hotel: فندق كلاسيك
# mikhaylovskoye - nearest hotel: No hotel found
# wamba - nearest hotel: No hotel found
# korla - nearest hotel: Silver Star Hotel
# panchagarh - nearest hotel: No hotel found
# tobol'sk - nearest hotel: Ямская
# fort saskatchewan - nearest hotel: No hotel found
# karratha - nearest hotel: Karratha International Hotel
# choibalsan - nearest hotel: Зүүн Ордон Зочид Буудал
# san juan bautista - nearest hotel: Hacienda San Juan Resort & Spa
# crane - nearest hotel: No hotel found
# ballina - nearest hotel: Ballina Beach Resort
# minzhu - nearest hotel: No hotel found
# al muharraq - nearest hotel: GAME 55 Home
# skowhegan - nearest hotel: No hotel found
# badr hunayn - nearest hotel: No hotel found
# fort bragg - nearest hotel: Airborne Inn Lodging
# bazhovo - nearest hotel: Славянка
# rawson - nearest hotel: Hotel Deportivo
# jamestown - nearest hotel: DoubleTree Jamestown
# aoulef - nearest hotel: دار الضياف
# tanque verde - nearest hotel: No hotel found
# bushehr - nearest hotel: هتل رستوران سیراف
# gluckstadt - nearest hotel: Christian IV
# viedma - nearest hotel: Níjar
# prince george - nearest hotel: Travelodge by Wyndham Prince George
# allapalli - nearest hotel: No hotel found
# east ballina - nearest hotel: Ballina Beach Resort
# nenjiang - nearest hotel: No hotel found
# brandon - nearest hotel: Brandon Motor Lodge
# south hedland - nearest hotel: Port Haven
# tselinnoye - nearest hotel: Гостиница
# sierra grande - nearest hotel: Sierra Grande
# patterson - nearest hotel: Hampton Inn & Suites
# menongue - nearest hotel: No hotel found
# springbok - nearest hotel: Elkoweru Guesthouse
# north platte - nearest hotel: Howard Johnson Inn - North Platte
# chaman - nearest hotel: No hotel found
# oujda-angad - nearest hotel: No hotel found
# ulysses - nearest hotel: No hotel found
# itaueira - nearest hotel: No hotel found
# longboat key - nearest hotel: Zota Beach Resort
# bayanaul - nearest hotel: Жан
# goz beida - nearest hotel: No hotel found
# east wenatchee bench - nearest hotel: No hotel found
# mhamid - nearest hotel: Hotel Kasbah Azalay
# belyy yar - nearest hotel: No hotel found
# chadron - nearest hotel: Holiday Inn Express & Suites Chadron
# kachia - nearest hotel: No hotel found
# rakops - nearest hotel: Rakops River Lodge
# urzhar - nearest hotel: Sharikan
# kyzylorda - nearest hotel: Нур
# nili - nearest hotel: No hotel found
# ceerigaabo - nearest hotel: Sanaag Hotel
# dalhart - nearest hotel: La Quinta Inn & Suites by Wyndham Dalhart
# fada - nearest hotel: No hotel found
# yarkovo - nearest hotel: No hotel found
# vera - nearest hotel: Hotel La Giralda
# chernyshevsk - nearest hotel: Карина
# tomatlan - nearest hotel: Hotel Hacienda Vieja Tomatlan
# tubarjal - nearest hotel: No hotel found
# recani - nearest hotel: Hotel Merzouga
# fittja - nearest hotel: Slagsta Gate Hotell
# san luis de la loma - nearest hotel: No hotel found
# flin flon - nearest hotel: Copperbelt Hotel
# zaragoza - nearest hotel: Hotel Pilar Plaza
# krasnoslobodsk - nearest hotel: Hilton Garden Inn Volgograd
# fairfield - nearest hotel: HI-HO Motel
# smithers - nearest hotel: Sunshine Inn Hotel
# klyuchi - nearest hotel: No hotel found
# ottawa - nearest hotel: Best Western Plus Ottawa Downtown Suites
# talagang - nearest hotel: Al husnain hotel
# sao vicente - nearest hotel: Pousada Vitória
#             City Country      Lat       Lng  Humidity  \
# 14        bethel      US  41.3712  -73.4140        35
# 17        albany      US  42.6001  -73.9662        34
# 19     ituiutaba      BR -18.9689  -49.4650        51
# 41    strezhevoy      RU  60.7333   77.5889        53
# 48          tura      IN  25.5198   90.2201        32
# ..           ...     ...      ...       ...       ...
# 539     smithers      CA  54.7804 -127.1743        38
# 545      klyuchi      RU  52.2667   79.1667        25
# 554       ottawa      CA  45.4112  -75.6981        25
# 558     talagang      PK  32.9297   72.4158        44
# 560  sao vicente      BR -23.9631  -46.3919        47
#
#                                    Hotel Name
# 14                        Hampton Inn Danbury
# 17                             No hotel found
# 19                               Hotel Bernal
# 41                      Гостиница "Сибирячка"
# 48                             No hotel found
# ..                                        ...
# 539                        Sunshine Inn Hotel
# 545                            No hotel found
# 554  Best Western Plus Ottawa Downtown Suites
# 558                          Al husnain hotel
# 560                           Pousada Vitória
#
# [89 rows x 6 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
mapped_city= hotel_df.hvplot.points(
    'Lng',
    'Lat',
    geo= True,
    size= 'Humidity',
    scale= 1,
    color= 'City',
    alpha=.5,
    tiles= 'CartoLight',
    frame_width= 750,
    frame_height= 500,
    hover_cols= ['Hotel Name', 'Country'],
    xlabel='Latidute',
    ylabel= 'Longitude',
    title= 'Hotels in Ideal Climate'
)
# Display the map
mapped_city
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
